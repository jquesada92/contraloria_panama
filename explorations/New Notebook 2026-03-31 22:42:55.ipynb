# %%
import pyspark.sql.functions as F

# %%
staging_df = spark.read.parquet('/Workspace/Users/jaquesada92@outlook.com/contraloria_panama/staging')

# %%
staging_df.where('fecha_consulta=="2026-03-16T08:20:19.000+00:00"').count()

# %%
tb_df = spark.read.table('contraloria.employee_payroll.employee_payroll_latest_snapshot')

# %%
print(tb_df.count())
tb_df.display()

# %%
# %sql select count('*') from contraloria.employee_payroll.bronze_contraloria_employees_raw

# %%
# %sql select count('*') from contraloria.employee_payroll.bronze_contraloria_employees_scd_type2
